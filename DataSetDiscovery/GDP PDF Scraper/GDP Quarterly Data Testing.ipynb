# %%
import tabula
import pandas as pd
import re

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# # 2014 Quarterly Data Test

# %%
GDP2014 = tabula.read_pdf('GDP2014_quarterly.pdf', pages = 7, stream = True)
GDP2014
# Out:
# [                         Unnamed: 0  Unnamed: 1  Unnamed: 2  \
#  0                               NaN         NaN         NaN
#  1                               NaN        2014         NaN
#  2                               NaN         NaN           I
#  3     United States1 ..............  17,316,314  16,941,430
#  4       New England ...............     924,937     911,347
#  5       Connecticut ...............     253,036     249,336
#  6       Maine .....................      55,838      54,800
#  7           Massachusetts .........     459,937     454,249
#  8           New Hampshire .........      71,552      69,842
#  9         Rhode Island ............      54,960      54,103
#  10       Vermont ..................      29,613      29,016
#  11    Mideast .....................   3,143,366   3,087,518
#  12      Delaware ..................      62,756      61,094
#  13         District of Columbia ...     115,473     115,482
# ...

# %%
GDP2014 = pd.concat(GDP2014, ignore_index = True)

# %%
GDP2014
# Out:
#                          Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                               NaN         NaN         NaN
# 1                               NaN        2014         NaN
# 2                               NaN         NaN           I
# 3     United States1 ..............  17,316,314  16,941,430
# 4       New England ...............     924,937     911,347
# 5       Connecticut ...............     253,036     249,336
# 6       Maine .....................      55,838      54,800
# 7           Massachusetts .........     459,937     454,249
# 8           New Hampshire .........      71,552      69,842
# 9         Rhode Island ............      54,960      54,103
# 10       Vermont ..................      29,613      29,016
# 11    Mideast .....................   3,143,366   3,087,518
# 12      Delaware ..................      62,756      61,094
# 13         District of Columbia ...     115,473     115,482
# 14      Maryland ..................     348,631     341,031
# ...

# %%
GDP2014 = GDP2014.drop(GDP2014.index[0]).reset_index(drop = True)
GDP2014 = GDP2014.drop(GDP2014.index[0]).reset_index(drop = True)
GDP2014
# Out:
#                          Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                               NaN         NaN           I
# 1     United States1 ..............  17,316,314  16,941,430
# 2       New England ...............     924,937     911,347
# 3       Connecticut ...............     253,036     249,336
# 4       Maine .....................      55,838      54,800
# 5           Massachusetts .........     459,937     454,249
# 6           New Hampshire .........      71,552      69,842
# 7         Rhode Island ............      54,960      54,103
# 8        Vermont ..................      29,613      29,016
# 9     Mideast .....................   3,143,366   3,087,518
# 10      Delaware ..................      62,756      61,094
# 11         District of Columbia ...     115,473     115,482
# 12      Maryland ..................     348,631     341,031
# 13       New Jersey ...............     549,099     539,958
# 14      New York ..................   1,404,518   1,378,213
# ...

# %% [markdown]
# ### Quarterly data is super messy and will require a lot of data cleaning. Need to check and see if the other quarterly data have similar issues or if each PDF will be unique.

# %% [markdown]
# # 2015 Quarterly Data Test

# %%
GDP15_16 = tabula.read_pdf('GDP2015-2016_quarterly.pdf', pages = 10, stream = True)
GDP15_16
# Out:
# [                           Unnamed: 0                            Unnamed: 1  \
#  0                                 NaN                                   NaN
#  1                                 NaN                                   NaN
#  2                                 NaN                                    Q1
#  3                                   1                                   NaN
#  4                       United States  ..........................17,671,025
#  5   New England .....................                               941,945
#  6        Connecticut ................                               250,628
#  7      Maine ........................                                55,930
#  8          Massachusetts ............                               478,320
#  9           New Hampshire ...........                                72,395
#  10        Rhode Island ..............                                54,858
# ...

# %%
GDP15_16 = pd.concat(GDP15_16, ignore_index = True)
GDP15_16
# Out:
#                            Unnamed: 0                            Unnamed: 1  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                    Q1
# 3                                   1                                   NaN
# 4                       United States  ..........................17,671,025
# 5   New England .....................                               941,945
# 6        Connecticut ................                               250,628
# 7      Maine ........................                                55,930
# 8          Massachusetts ............                               478,320
# 9           New Hampshire ...........                                72,395
# 10        Rhode Island ..............                                54,858
# ...

# %% [markdown]
# ### It looks like the tables with more than one year are even messier. It will probably be best to treat 2014 as a unique year and then write a class for the 2015 - 2020 data since those all have multiple years in one table.
