# %%
# !pip install tabula-py

# %%
import tabula

# %%
# !java -version
# Out:
# java version "1.8.0_261"
# Java(TM) SE Runtime Environment (build 1.8.0_261-b12)
# Java HotSpot(TM) Client VM (build 25.261-b12, mixed mode)

# %%
df = tabula.read_pdf('h150-11.pdf', pages = "79-81", stream = True)

# %%
df[0]
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                               Value
# 8   Less than $10,000 . . . . . . . . . . . . . . ...
# 9   $10,000 to $19,999 . . . . . . . . . . . . . ....
# 10  $20,000 to $29,999 . . . . . . . . . . . . . ....
# 11  $30,000 to $39,999 . . . . . . . . . . . . . ....
# 12  $40,000 to $59,999 . . . . . . . . . . . . . ....
# 13  $60,000 to $79,999 . . . . . . . . . . . . . ....
# 14  $80,000 to $99,999 . . . . . . . . . . . . . ....
# 15   $100,000 to $119,999 . . . . . . . . . . . . . .
# ...
