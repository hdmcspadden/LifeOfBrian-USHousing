# %%
# resources: tabula-py documentation
# https://medium.com/analytics-vidhya/how-to-extract-multiple-tables-from-a-pdf-through-python-and-tabula-py-6f642a9ee673

# !java -version
# Out:
# openjdk version "11.0.8" 2020-07-14 LTS
# OpenJDK Runtime Environment Zulu11.41+23-CA (build 11.0.8+10-LTS)
# OpenJDK 64-Bit Server VM Zulu11.41+23-CA (build 11.0.8+10-LTS, mixed mode)

# %%
import tabula
import pandas as pd

# %%
tabula.environment_info()
# Out:
# Python version:
#     3.8.3 (default, Jul  2 2020, 11:26:31)
# [Clang 10.0.0 ]
# Java version:
#     openjdk version "11.0.8" 2020-07-14 LTS
# OpenJDK Runtime Environment Zulu11.41+23-CA (build 11.0.8+10-LTS)
# OpenJDK 64-Bit Server VM Zulu11.41+23-CA (build 11.0.8+10-LTS, mixed mode)
# tabula-py version: 1.4.1
# platform: macOS-10.15.7-x86_64-i386-64bit
# uname:
#     uname_result(system='Darwin', node='Jordans-Workbook.local', release='19.6.0', version='Darwin Kernel Version 19.6.0: Mon Aug 31 22:12:52 PDT 2020; root:xnu-6153.141.2~1/RELEASE_X86_64', machine='x86_64', processor='i386')
# linux_distribution: ('Darwin', '19.6.0', '')
# mac_ver: ('10.15.7', ('', '', ''), 'x86_64')

# %%
pdf_path = "https://www.census.gov/history/pdf/histstats-colonial-1970.pdf"

dfs = tabula.read_pdf(pdf_path, pages=24, multiple_tables=True, stream=True)
dfs
# Out:
# [                0                                  1                       2  \
#  0             NaN                                NaN                     NaN
#  1             NaN                                NaN                    ----
#  2             NaN                               Land                     NaN
#  3             NaN                               area                     NaN
#  4             NaN                                NaN                     NaN
#  5            Year                             miles)                  Number
#  6             NaN                                NaN                     NaN
#  7             NaN                                NaN                     NaN
#  8             NaN                                  I                     NaN
#  9   1970 (Apr. 1)                          3,536,855                     NaN
#  10  1960 (Apr. 1)    3,540,911179,323,175 28,625,614                     NaN
# ...
