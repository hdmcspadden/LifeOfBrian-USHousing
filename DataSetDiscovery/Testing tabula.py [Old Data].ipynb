# %%
# !pip install tabula-py

# %%
import tabula

# %%
# !java -version
# Out:
# java version "1.8.0_261"
# Java(TM) SE Runtime Environment (build 1.8.0_261-b12)
# Java HotSpot(TM) Client VM (build 25.261-b12, mixed mode)

# %%
df = tabula.read_pdf('mortstatsh_1918.pdf', pages = 29)
# Out:
# Got stderr: Sep 30, 2020 10:38:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font TimesNewRomanPSMT for NewCenturySchlbk-Roman
# Sep 30, 2020 10:38:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font TimesNewRomanPSMT for Bookman-Light
# Sep 30, 2020 10:38:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font Arial-BoldMT for Helvetica-Condensed-Black
# Sep 30, 2020 10:38:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font TimesNewRomanPSMT for Palatino-Roman
# Sep 30, 2020 10:38:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font Arial-BoldMT for Helvetica-Narrow-Bold
# Sep 30, 2020 10:38:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font TimesNewRomanPSMT for NewCenturySchlbk-Roman
# Sep 30, 2020 10:38:17 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# ...

# %%
df[2]
# Out:
#                     . . . .. . . . . . . . . . . 2,12  Unnamed: 0    114  \
# 0        Colored. .. . . . . . . . . . . . . . . . 28         NaN      &
# 1       Cleveland, Ohio. . . . . . . . . . . . . 4,48         NaN    33{
# 2                   Columbus,C)hio(total) . . . . . .         NaN     7!
# 3      White . . . . . . . . . . . . . . . . . . . :;         NaN     5{
# 4       Colored... . . . . . . . . . . . . . . . . 13         NaN     1[
# 5        Dayton, Olmo. . . . . . . . . . . . . . . 76         NaN     6;
# 6         Toledo, Ohio. . . . . . . . . . . . . . . .         NaN     8\
# 7         Portkmd, Ore . . . . . . . . . . . . .. 1,E         NaN    NaN
# 8             milmm13eMa-$, a.(total) . . . . . 16,26         NaN   1,3:
# 9           . . . . . . . . . . . . . . . . . . 14,80         NaN  1,14!
# 10       Colored. .. . . . . . . . . . . . . . . 1>45         NaN    15;
# 11                                                NaN         NaN    NaN
# ...
